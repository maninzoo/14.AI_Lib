# %%
# !ollama run qwen2.5
# Out:
# >>> Send a message (/? for help)/bye
# ...

# %%
# !pip install ollama
# !pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 6.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 100.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 24.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 86.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 96.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 21.1 MB/s eta 0:00:00
# ...

# %%
# !pip install sentence_transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 104.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
import ollama
llm = "qwen2.5"

# %%
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings

# 한국어 지원 모델 로드
model = SentenceTransformer('paraphrase-multilingual-MiniLM-L12-v2')

# 커스텀 임베딩 함수 클래스 정의
class KoreanEmbeddingFunction(EmbeddingFunction):
    def __init__(self):
        self.model = model

    def __call__(self, input: Documents) -> Embeddings:
        return self.model.encode(input).tolist()

    def name(self) -> str:
        return "korean_embedding_function"

## connect to db
db = chromadb.PersistentClient()

## check existing collections
db.list_collections()

## select a collection
collection_name = "chat_history_ko"
collection = db.get_or_create_collection(
    name=collection_name,
    embedding_function=KoreanEmbeddingFunction()
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/645 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/471M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# ...

# %%
from datetime import datetime

def save_chat(lst_msg, collection):
    print("--- Saving Chat ---")

    ## extract chat
    chat = ""
    for m in lst_msg:
        chat += f'{m["role"]}: <<{m["content"]}>>' + '\n\n'

    ## get_idx
    idx = str(collection.count() + 1)

    ## generate info
    p = "다음 대화를 설명하는 데 3개의 키워드만 사용하세요 (예: '금융, 변동성, 주식')."
    tags = ollama.generate(model=llm, prompt=p+"\n"+chat)["response"]
    dic_info = {"tags":tags,
                "date": datetime.today().strftime("%Y-%m-%d"),
                "time": datetime.today().strftime("%H-%M")}

    ## write db
    collection.add(documents=[chat], ids=[idx], metadatas=[dic_info])
    print(f"--- Chat num {idx} saved ---","\n")
    print(dic_info,"\n")
    print(chat)
    print("------------------------")

# %%
prompt = "당신은 사용자 요청에 최적의 답변을 제공하는 지능형 어시스턴트입니다."
messages = [{"role":"system", "content":prompt}]

while True:
  ## User
  q = input('🙂 >')
  if q == "quit":
    ### save chat before quitting
    save_chat(lst_msg=messages, collection=collection)
    break
  messages.append( {"role":"user", "content":q} )

  ## Model
  agent_res = ollama.chat(model=llm, messages=messages, tools=[])
  res = agent_res["message"]["content"]

  ## Response
  print("👽 >", f"\x1b[1;30m{res}\x1b[0m")
  messages.append( {"role":"assistant", "content":res} )
# Out:
# 🙂 >안녕
# 👽 > 안녕하세요! 어떻게 도와드릴까요?
# 🙂 >나는 초콜릿에 심각한 알레르기가 있어요. 목숨이 위험할 수도 있어요.
# 👽 > 죄송합니다, 이런 문제를 알고 있어야 합니다. 즉시 의료 지원을 받으세요. 전문의에게 상담하여 치료 계획과 음식 섭취에 대한 조언을 받는 것이 중요합니다. 집에서 스스로 치료하지 마세요. 목숨이 위험한 알레르기라면, 의료진은 신속하게 대처해야 합니다. 현황을 설명하고 필요한 경우 경고약을 사용하세요.
# 🙂 >quit
# --- Saving Chat ---
# --- Chat num 1 saved ---
#
# {'tags': '알레르기, 즉시 지원, 의료진', 'date': '2025-07-13', 'time': '05-43'}
#
# system: <<당신은 사용자 요청에 최적의 답변을 제공하는 지능형 어시스턴트입니다.>>
#
# user: <<안녕>>
#
# assistant: <<안녕하세요! 어떻게 도와드릴까요?>>
#
# user: <<나는 초콜릿에 심각한 알레르기가 있어요. 목숨이 위험할 수도 있어요.>>
#
# assistant: <<죄송합니다, 이런 문제를 알고 있어야 합니다. 즉시 의료 지원을 받으세요. 전문의에게 상담하여 치료 계획과 음식 섭취에 대한 조언을 받는 것이 중요합니다. 집에서 스스로 치료하지 마세요. 목숨이 위험한 알레르기라면, 의료진은 신속하게 대처해야 합니다. 현황을 설명하고 필요한 경우 경고약을 사용하세요.>>
#
#
# ------------------------

# %%
def retrieve_chat(query:str) -> str:
    res_db = collection.query(query_texts=[query])["documents"][0][0:10]
    history = ' '.join(res_db).replace("\n", " ")
    return history

tool_retrieve_chat = {'type':'function', 'function':{
    'name': 'retrieve_chat',
    'dsscription': 'When you knowledge is NOT enough to answer the user, you can use this tool to retrieve chats history.',
    'parameters': {'type': 'object',
                   'required': ['query'],
                   'properties': {
                       'query': {'type':'str', 'description':'Input the user question or the topic of the current chat'}
}}}}

## test
retrieve_chat(query="초콜릿")
# Out:
# 'system: <<당신은 사용자 요청에 최적의 답변을 제공하는 지능형 어시스턴트입니다.>>  user: <<안녕>>  assistant: <<안녕하세요! 어떻게 도와드릴까요?>>  user: <<나는 초콜릿에 심각한 알레르기가 있어요. 목숨이 위험할 수도 있어요.>>  assistant: <<죄송합니다, 이런 문제를 알고 있어야 합니다. 즉시 의료 지원을 받으세요. 전문의에게 상담하여 치료 계획과 음식 섭취에 대한 조언을 받는 것이 중요합니다. 집에서 스스로 치료하지 마세요. 목숨이 위험한 알레르기라면, 의료진은 신속하게 대처해야 합니다. 현황을 설명하고 필요한 경우 경고약을 사용하세요.>>  '

# %%
def final_answer(text:str) -> str:
    return text

tool_final_answer = {'type':'function', 'function':{
    'name': 'final_answer',
    'dsscription': 'Returns a natural language response to the user',
    'parameters': {'type': 'object',
                   'required': ['text'],
                   'properties': {'text': {'type':'str', 'description':'natural language response'}}
}}}

# %%
dic_tools = {'retrieve_chat':retrieve_chat,
             'final_answer':final_answer}

# %%
def use_tool(agent_res:dict, dic_tools:dict) -> dict:
    ## use tool
    if agent_res["message"].tool_calls is not None:
        for tool in agent_res["message"].tool_calls:
            t_name, t_inputs = tool["function"]["name"], tool["function"]["arguments"]
            if f := dic_tools.get(t_name):
                ### calling tool
                print('🔧 >', f"\x1b[1;31m{t_name} -> Inputs: {t_inputs}\x1b[0m")
                ### tool output
                t_output = f(**tool["function"]["arguments"])
                print(t_output)
                ### final res
                res = t_output
            else:
                print('🤬 >', f"\x1b[1;31m{t_name} -> NotFound\x1b[0m")
    ## don't use tool
    else:
        res = agent_res["message"].content
        t_name, t_inputs = '', ''
    return {'res':res, 'tool_used':t_name, 'inputs_used':t_inputs}

# %%
def run_agent(llm, messages, available_tools):
    ## use tools until final answer
    tool_used, local_memory = '', ''
    while tool_used != 'final_answer':
        ### use tool
        try:
            agent_res = ollama.chat(model=llm, messages=messages, tools=[v for v in available_tools.values()])
            dic_res = use_tool(agent_res, dic_tools)
            res, tool_used, inputs_used = dic_res["res"], dic_res["tool_used"], dic_res["inputs_used"]
        ### error
        except Exception as e:
            print("⚠️ >", e)
            res = f"I tried to use {tool_used} but didn't work. I will try something else."
            print("👽 >", f"\x1b[1;30m{res}\x1b[0m")
            messages.append( {"role":"assistant", "content":res} )
        ### update memory
        if tool_used not in ['','final_answer']:
            local_memory += f"\n{res}"
            messages.append( {"role":"assistant", "content":local_memory} )
            available_tools.pop(tool_used)
            if len(available_tools) == 1:
                messages.append( {"role":"user", "content":"이제 final_answer tool 을 활성화합니다."} )
        ### tools not used
        if tool_used == '':
            break
    return res

# %%
prompt = '''
당신은 지능형 어시스턴트로서 사용자의 요청에 가장 적합한 답변을 자연스러운 한국어로 제공합니다.
사용자와 상호작용할 때는 먼저 'retrieve_chat' 도구를 사용해 이전 대화 기록을 확인해야 합니다.
'''
messages = [{"role":"system", "content":prompt}]

while True:
  ## User
  q = input('🙂 >')
  if q == "quit":
    ### save chat before quitting
    save_chat(lst_msg=messages, collection=collection)
    break
  messages.append( {"role":"user", "content":q} )

  ## Model
  available_tools = {"retrieve_chat":tool_retrieve_chat,"final_answer":tool_final_answer}
  res = run_agent(llm, messages, available_tools)

  ## Response
  print("👽 >", f"\x1b[1;30m{res}\x1b[0m")
  messages.append( {"role":"assistant", "content":res} )
# Out:
# 🙂 >안녕
# 👽 > 안녕하세요! 어떻게 도와드릴까요?
# 🙂 >브라우니 레시피를 알려줘.
# 👽 > ortal
# {"name": "retrieve_chat", "arguments": {"query": "브라우니 레시피"}}
# </tool_call>
# 🙂 >브라우니 레시피를 알려줘.
# 👽 > 보내드린 레시피에 따르면, 먼저 알레르기 반응을 일으키지 않는 베이킹 소다 1/4 티스푼과 바닐라 추출물 1티스푼을 섞습니다.
#
# 건포도 3/4컵과 블랙러시아나무 가루 2대술, 그리고 설탕 1컵을 버터와 함께 조심조심 저어줍니다.
#
# 그리고 밀가루 1/2컵과 코코아 파우더 3/4컵을 섞는 것이 좋습니다.
#
# 이 모든 재료들을 큰 그릇에 넣고 잘 섞은 후, 브라운니 팬에 버터를 두르고 부어줍니다.
#
# 마지막으로 레시피를 따라 저글링하여 325°F(160°C)에서 20분 동안 굽는 것입니다.
#
# 브라우니가 겉은 살짝 간단하고, 안은 흰색이 되면 완성됩니다.
#
# 맛있게 만들어보세요! 이 레시피에 따라 조리해 보셨나요? 더 도와드릴 것이 있으신가요?
# 🙂 >quit
# --- Saving Chat ---
# --- Chat num 2 saved ---
#
# {'tags': '재료, 굽기, 섞기', 'date': '2025-07-13', 'time': '05-45'}
#
# system: <<
# 당신은 지능형 어시스턴트로서 사용자의 요청에 가장 적합한 답변을 자연스러운 한국어로 제공합니다.
# 사용자와 상호작용할 때는 먼저 'retrieve_chat' 도구를 사용해 이전 대화 기록을 확인해야 합니다.
# >>
#
# user: <<안녕>>
#
# assistant: <<안녕하세요! 어떻게 도와드릴까요?>>
#
# user: <<브라우니 레시피를 알려줘.>>
#
# assistant: <<ortal
# {"name": "retrieve_chat", "arguments": {"query": "브라우니 레시피"}}
# </tool_call>>>
#
# ...
