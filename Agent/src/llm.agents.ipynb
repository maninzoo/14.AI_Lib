# %%
## setup
import ollama
llm = "qwen2.5"

## question
q = "What is 30 multiplied by 10?"

# %%
response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content':q}
])
print(response['message']['content'])
# Out:
# 30 multiplied by 10 equals 300.

# %%
prompt = '''
To solve the task, you must plan forward to proceed in a series of steps, in a cycle of 'Thought:', 'Action:', and 'Observation:' sequences.
At each step, in the 'Thought:' sequence, you should first explain your reasoning towards solving the task, then the tools that you want to use.
Then in the 'Action:' sequence, you should use one of your tools.
During each intermediate step, you can use 'Observation:' field to save whatever important information you will use as input for the next step.
'''

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content':q+" "+prompt}
])    
print(response['message']['content'])
# Out:
# Thought: To solve this multiplication problem (30 * 10), I don't need any external tools. This is a straightforward arithmetic operation that can be performed mentally or on paper. The thought process here would simply involve multiplying the digits, considering their place values.
#
# Action: Since no tool is needed, I will proceed with the calculation directly.
# Observation: 30 multiplied by 10 equals 300.
#
# Answer: 30 multiplied by 10 is 300.

# %%
prompt = '''Let's think step by step.'''

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content':q+" "+prompt}
])    
print(response['message']['content'])
# Out:
# Sure, let's break it down step by step:
#
# Step 1: Understand the multiplication.
# Multiplying 30 by 10 means you have 30 of something, and each of those somethings is 10.
#
# Step 2: Perform the calculation.
# To multiply 30 by 10, you can think of it as adding a zero to 30 because multiplying by 10 moves the decimal point one place to the right (or equivalently, adds a zero at the end in whole numbers).
#
# So:
# - 30 becomes 300 when multiplied by 10.
#
# Therefore, 30 multiplied by 10 equals 300.

# %%
cot_answer = response['message']['content']

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content': f'''Here was your original answer:\n\n{cot_answer}\n\n
                                Now reflect on whether it was correct or if it was the best approach.
                                If not, correct your reasoning and answer.'''}
])
print(response['message']['content'])
# Out:
# Your original response is actually quite accurate and clear in explaining how to multiply 30 by 10. However, there's a small refinement that can make the explanation even more precise.
#
# ### Revised Explanation
#
# Sure, let's break it down step by step:
#
# Step 1: Understand the multiplication.
# Multiplying 30 by 10 means you have 30 of something, and each of those somethings is 10.
#
# Step 2: Perform the calculation.
# To multiply 30 by 10, you can think of it as moving the decimal point in 30 one place to the right (or equivalently, adding a zero at the end since 30 is already a whole number).
#
# So:
# - Moving the decimal point one place to the right in 30 changes it from \(30.\) (which is 30.0) to 300.
#
# Therefore, 30 multiplied by 10 equals **300**.
#
# This approach reinforces the concept of how multiplication by 10 affects the placement of digits and can be particularly useful for understanding place value and decimal operations.

# %%
num_branches = 3

prompt = f'''
You will think of multiple reasoning paths (thought branches). For each path, write your reasoning and final answer.
After exploring {num_branches} different thoughts, pick the best final answer and explain why.
'''

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content': f"Task: {q} \n{prompt}"}
])
print(response['message']['content'])
# Out:
# Certainly! Let's explore three different reasoning paths to solve the multiplication problem \(30 \times 10\).
#
# ### Reasoning Path 1: Direct Multiplication
#
# **Reasoning:**
# - Directly multiply 30 by 10.
# - This is a straightforward calculation where we can think of it as shifting the decimal point one place to the right for the number 30 (considered as 30.0) and then adding a zero at the end, which gives us 300.
#
# **Final Answer:**
# - \(30 \times 10 = 300\)
#
# ### Reasoning Path 2: Distributive Property
#
# **Reasoning:**
# - We can break down the problem using the distributive property of multiplication over addition.
# - Consider \(30 \times 10\) as \( (3 \times 10) \times 10 \).
# - First, calculate \(3 \times 10 = 30\).
# - Then multiply the result by 10: \(30 \times 10 = 300\).
#
# **Final Answer:**
# - \(30 \times 10 = 300\)
#
# ### Reasoning Path 3: Place Value Understanding
#
# **Reasoning:**
# - Recognize that multiplying a number by 10 increases its place value.
# - The number 30 has a digit 3 in the tens place. Multiplying it by 10 shifts this 3 to the hundreds place, making it 300.
#
# **Final Answer:**
# - \(30 \times 10 = 300\)
#
# ### Conclusion
#
# After exploring these three paths, all lead us to the same final answer:
#
# **Best Final Answer:** \(30 \times 10 = 300\).
#
# All reasoning paths are valid and give the same result. The best answer is simply the correct calculation of \(30 \times 10\), which equals 300, confirmed by multiple logical approaches.

# %%
prompt = '''
Think step-by-step but allow yourself to revisit and revise earlier steps if needed.
Describe your thoughts as nodes connected by reasoning links.
Explore at least 2 paths, show their connections, and converge on a final answer.
'''

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content': f"Task: {q} \n{prompt}"}
])
print(response['message']['content'])
# Out:
# ### Path 1: Direct Multiplication
#
# 1. **Node 1:** Start with the numbers 30 and 10.
#    - Reasoning Link: These are the given numbers for multiplication.
#
# 2. **Node 2:** Break down 30 into its components (3 * 10).
#    - Reasoning Link: Breaking it down makes the multiplication easier to visualize and understand.
#
# 3. **Node 3:** Multiply each component of 30 by 10.
#    - Step A: 3 * 10 = 30
#      - Reasoning Link: Any number multiplied by 10 is that number with a zero added at the end.
#    - Step B: 10 * 10 = 100
#      - Reasoning Link: Multiplying the tens place of 30 (which is just 10) directly by 10 results in 100.
#
# 4. **Node 4:** Combine the results from Steps A and B.
#    - Step C: Add 30 + 100 = 130
#      - Reasoning Link: Since these are parts of the same number, we can add them together to get the final product.
#
# 5. **Final Answer: 130**
#    - Reasoning Link: This is the result after combining the individual multiplications.
#
# ### Path 2: Simplified Multiplication
#
# 1. **Node A:** Start with the numbers 30 and 10.
#    - Reasoning Link: These are the given numbers for multiplication.
#
# 2. **Node B:** Recognize that multiplying by 10 is equivalent to shifting a number one place to the left (or appending a zero).
#    - Reasoning Link: This is a fundamental property of base-10 arithmetic.
#
# 3. **Node C:** Apply this rule directly.
#    - Step D: Shift 30 one place to the left, effectively adding a zero at the end.
#      - Reasoning Link: Shifting a number by one position in base-10 notation multiplies it by 10.
#
# 4. **Final Answer: 300**
#    - Reasoning Link: This result is derived directly from the rule of shifting digits when multiplying by 10, but we need to correct this path since our earlier steps showed a different answer.
#
# ### Revisiting and Convergence
#
# Upon reviewing both paths, it becomes clear that Path 2 initially suggested an incorrect step due to the misunderstanding in applying the zero appending method. The direct multiplication (Path 1) correctly shows that 30 * 10 is indeed 300, but the breakdown into components of 30 helped simplify the process.
#
# Therefore, revisiting and combining both approaches converges on the correct answer:
#
# - **Correct Final Answer: 300**
#
# This final result aligns with mathematical principles and direct computation.

# %%
class GoT:
    def __init__(self, question):
        self.question = question
        self.nodes = {}  # node_id: text
        self.edges = []  # (from_node, to_node, relation)
        self.counter = 1

    def add_node(self, text):
        node_id = f"Thought{self.counter}"
        self.nodes[node_id] = text
        self.counter += 1
        return node_id

    def add_edge(self, from_node, to_node, relation):
        self.edges.append((from_node, to_node, relation))

    def show(self):
        print("\n--- Current Thoughts ---")
        for node_id, text in self.nodes.items():
            print(f"{node_id}: {text}\n")
        print("--- Connections ---")
        for f, t, r in self.edges:
            print(f"{f} --[{r}]--> {t}")
        print("\n")

    def expand_thought(self, node_id):
        prompt = f"""
        You are reasoning about the task: {self.question}
        Here is a previous thought node ({node_id}):\"\"\"{self.nodes[node_id]}\"\"\"
        Please provide a refinement, an alternative viewpoint, or a related thought that connects to this node.
        Label your new thought clearly, and explain its relation to the previous one.
        """
        response = ollama.chat(model=llm, messages=[{'role':'user', 'content':prompt}])
        return response['message']['content']

## Start Graph
g = GoT(q)

## Get initial thought
response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content':q}
])
n1 = g.add_node(response['message']['content'])

## Expand initial thought with some refinements
refinements = 1
for _ in range(refinements):
    expansion = g.expand_thought(n1)
    n_new = g.add_node(expansion)
    g.add_edge(n1, n_new, "expansion")
    g.show()

## Final Answer
prompt = f'''
Here are the reasoning thoughts so far:
{chr(10).join([f"{k}: {v}" for k,v in g.nodes.items()])}
Based on these, select the best reasoning and final answer for the task: {q}
Explain your choice.
'''

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content':prompt}
])
print(response['message']['content'])
# Out:
# --- Current Thoughts ---
# Thought1: 30 multiplied by 10 equals 300.
#
# Thought2: ### Thought2: "Multiplying 30 by 10 can also be understood as adding 30 to itself 10 times."
#
# **Relation to Thought1:** This thought provides an alternative way of understanding the multiplication operation, which is closely related to the direct calculation given in Thought1. Instead of performing the multiplication directly (which yields 300), this approach breaks down the process into a series of additions, making it easier to grasp for those who might prefer or benefit from seeing arithmetic operations as repeated addition.
#
# For instance:
# - 30 + 30 + 30 + 30 + 30 + 30 + 30 + 30 + 30 + 30 = 300
#
# This method reinforces the concept that multiplication is essentially a shorthand for repeated addition, which can be particularly helpful in teaching foundational arithmetic concepts.
#
# --- Connections ---
# Thought1 --[expansion]--> Thought2
#
#
# The best reasoning for understanding \(30 \times 10\) involves both Thought1 and Thought2. Let's break down the selection process:
#
# - **Thought1**: Directly states that multiplying 30 by 10 results in 300, which is the numerical answer.
# - **Thought2**: Provides an alternative perspective on multiplication as repeated addition. It explains that \(30 \times 10\) can be understood as adding 30 to itself 10 times.
#
# ### Explanation:
#
# **Thought1** is straightforward and direct. It uses the standard arithmetic operation of multiplication to give the answer, which is concise and effective for immediate problem-solving.
#
# **Thought2** deepens understanding by explaining the underlying concept. For educational purposes or for those who are learning basic arithmetic, knowing that multiplication can be viewed as repeated addition helps in building a stronger foundational understanding of mathematical operations.
#
# ### Final Answer:
#
# The result of \(30 \times 10\) is **300**.
#
# - I chose this answer because it directly provides the correct numerical result while also offering an educational insight into how multiplication works. This dual approach ensures both accuracy and conceptual clarity, which are valuable in different contexts such as teaching or problem-solving.

# %%
import re

def extract_python_code(text):
    match = re.search(r"```python(.*?)```", text, re.DOTALL)
    if match:
        return match.group(1).strip()
    return None

def sandbox_exec(code):
    ## Create a minimal sandbox with safety limitation
    allowed_builtins = {'abs', 'min', 'max', 'pow', 'round'}
    safe_globals = {k: __builtins__.__dict__[k] for k in allowed_builtins if k in __builtins__.__dict__}
    safe_locals = {}
    exec(code, safe_globals, safe_locals)
    return safe_locals.get('result', None)

prompt = '''
Write a short Python program that calculates the answer and assigns it to a variable named 'result'.
Return only the code enclosed in triple backticks with 'python' (```python ... ```).
'''

response = ollama.chat(model=llm, messages=[
    {'role':'user', 'content': f"Task: {q} \n{prompt}"}
])
print(response['message']['content'])
sandbox_exec(code=extract_python_code(text=response['message']['content']))
# Out:
# ```python
# result = 30 * 10
# ```
# 300
